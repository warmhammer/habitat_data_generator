# %%
# %load_ext autoreload 
# %autoreload 2

# %matplotlib inline

# %%
import numpy as np
import hadage as hdg

# %%
DEBUG = False

# %%
# sim_settings_filename = 'examples/sim_settings_hm3d.json'
# sim_settings_filename = 'examples/sim_settings_replica_cad.json'
sim_settings_filename = 'examples/sim_settings_replica.json'

# %%
logger = hdg.ExperimentLogger(sim_settings_filename, display=True, package_dir_path='./', data_dir='/data')

sim_settings, light_settings = logger.get_settings()

# %%
try:
    sim.close()
except NameError:
    pass

sim = hdg.create_simulator(sim_settings)

# %%
sim_settings

# %%
start_point, navigatable_points = hdg.generate_scenario(sim, sim_settings)

# %%
logger.save_camera_params(sim, printed=True)

# %%
# start_point, rotation = [2.9, 0.0990586, 6.0], [0, 0.7071068, 0, 0.7071068]
# rotation = [0, 0.7071068, 0, 0.7071068]

# %%
sim = hdg.place_agent(sim, sim_settings['default_agent'], start_point) #, rotation)

# %%
sim.agents[sim_settings['default_agent']].get_state()

# %%
assert all(np.abs(sim.agents[sim_settings['default_agent']].get_state().position - start_point) < 1e-6)

# %%
if DEBUG:
    sim, _ = hdg.change_lights(sim, sim_settings, light_settings, life_index=0)
    hdg.do_test_steps(sim, sim_settings, max_frames=5)

# %%
hdg.run_scenario(sim, sim_settings, light_settings, navigatable_points, logger)

# %%
# !rm generated.zip
# !zip -r generated.zip generated/
